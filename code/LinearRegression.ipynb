# %% [markdown]
# <a href="https://colab.research.google.com/github/PratyushC290/learning-ml/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
class Linear_Regression():
  def __init__(self, alpha, it):

    self.alpha = alpha
    self.it = it

  def fit(self, X, Y):

    self.m, self.n = X.shape #m=rows,n=columns
    self.w = np.zeros(self.n)
    self.b = 0
    self.X = X
    self.Y = Y

#gradient descent
    for i in range (self.it):
      self.update_weights()

  def update_weights(self):

    Y_prediction = self.predict(self.X)

    dw = -(2*(self.X.T).dot(self.Y-Y_prediction))/self.m
    db = -2*np.sum(self.Y-Y_prediction)/self.m

    self.w = self.w- dw*self.alpha
    self.b = self.b - db*self.alpha

  def predict(self, X):

    return X.dot(self.w)+self.b

# %%
df = pd.read_csv('Salary_Data.csv')
X = df.iloc[:,:-1].values
y = df.iloc[:,1]

# %%
model = Linear_Regression(alpha = 0.02, it = 1000)
model.fit(X, y)
y_pred = model.predict(X)

# %%
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()
model.fit(X,y)
y_pred2 = model.predict(X)

# %%
import matplotlib.pyplot as plt
plt.plot(X,y_pred,color='blue')
plt.scatter(X,y,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(X,y_pred2,color='green')
plt.scatter(X,y,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(X,y_pred,color='blue')
plt.plot(X,y_pred2,color='green')
plt.scatter(X,y,color='red')
plt.show()
